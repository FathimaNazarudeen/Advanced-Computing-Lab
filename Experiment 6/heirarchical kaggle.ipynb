# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/Advanced-Computing-Lab/blob/main/Experiment%206/heirarchical%20kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
file=pd.read_csv("/content/heart.csv")
x=file[["age","sex","cp","trtbps","chol","fbs","restecg","thalachh","exng","oldpeak","slp","caa","thall"]][150:]

# %%
from sklearn.decomposition import PCA
pcamodel=PCA(n_components=2)
principalcomponents=pcamodel.fit_transform(x)
newx=pd.DataFrame(data=principalcomponents,columns=["PC1","PC2"])

# %%
xaxis=newx["PC1"]
yaxis=newx["PC2"]
newx
# Out:
#             PC1        PC2
# 0    -17.975982   4.578612
# 1    -99.557030  17.511436
# 2    -18.467640 -12.363604
# 3     31.013972 -10.029990
# 4    -28.101107 -12.357719
# ..          ...        ...
# 148   -6.437711  18.129476
# 149   14.307994   7.234712
# 150  -53.820528   1.716823
# 151 -116.775622  26.642320
# 152  -12.180787 -32.809460
#
# [153 rows x 2 columns]

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
Z = hierarchy.linkage(principalcomponents, 'complete')
plt.figure()
hierarchy.dendrogram(Z,orientation="top",above_threshold_color="red")
# Out:
# {'color_list': ['m',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'm',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
# ...
