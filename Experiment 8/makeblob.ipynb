# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/Advanced-Computing-Lab/blob/main/Experiment%208/makeblob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs

# %%
x, y = make_blobs(n_samples=2000, centers=2, n_features=2)

# %%
x
# Out:
# array([[ 2.45210025,  8.59914398],
#        [ 2.82799994,  8.03779577],
#        [ 4.7208191 ,  5.93725685],
#        ...,
#        [ 4.41654375,  8.95876583],
#        [ 1.97908007, 11.39990426],
#        [ 2.04680348,  7.15714169]])

# %%
y
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %%
import pandas as pd
new_df=pd.DataFrame(x,columns=["X_axis","Y_axis"])

# %%
new_df
# Out:
#         X_axis     Y_axis
# 0     2.452100   8.599144
# 1     2.828000   8.037796
# 2     4.720819   5.937257
# 3     2.143421   5.615512
# 4     2.210690   8.104261
# ...        ...        ...
# 1995  2.520333   9.672251
# 1996  2.106188   9.146752
# 1997  4.416544   8.958766
# 1998  1.979080  11.399904
# 1999  2.046803   7.157142
#
# [2000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
X_train
# Out:
# array([[2.58638041, 7.21502704],
#        [2.18613178, 6.35617874],
#        [3.59072174, 7.20575572],
#        ...,
#        [2.26016803, 9.0363166 ],
#        [1.41584631, 8.31507028],
#        [2.85766534, 8.78094985]])

# %%
X_train=pd.DataFrame(X_train,columns=["X_axis","Y_axis"])

# %%
X_train
# Out:
#         X_axis     Y_axis
# 0     2.586380   7.215027
# 1     2.186132   6.356179
# 2     3.590722   7.205756
# 3     1.107754  10.204557
# 4     2.686592   7.339749
# ...        ...        ...
# 1595  4.866053   7.218690
# 1596  2.298426   8.660185
# 1597  2.260168   9.036317
# 1598  1.415846   8.315070
# 1599  2.857665   8.780950
#
# [1600 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
x_axis=X_train["X_axis"]
y_axis=X_train["Y_axis"]
plt.scatter(x_axis,y_axis,s=10, cmap="y")
plt.xlabel("X")
plt.ylabel("Y")
plt.rcParams["figure.figsize"]=(10,8)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X_train)

# %%
c=kmeans.cluster_centers_
c
# Out:
# array([[2.36053645, 7.10440187],
#        [1.78068725, 9.28978205]])

# %%
import matplotlib.pyplot as plt
x_axis=X_train["X_axis"]
y_axis=X_train["Y_axis"]
labels=kmeans.labels_
plt.scatter(x_axis,y_axis, s=20,c=labels,cmap="rainbow")
plt.scatter(c[0][0],c[0][1],s=100,color="orange")
plt.scatter(c[1][0],c[1][1],s=100,color="green")

plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
X_test=pd.DataFrame(X_test,columns=["X_axis","Y_axis"])

# %%
res=kmeans.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(res, y_test)
print(acc*100)
# Out:
# 81.25
