# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/Advanced-Computing-Lab/blob/main/Experiment%204/decision_tree_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
file=load_iris()
X=file.data
Y=file.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.9,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
ml = DecisionTreeClassifier(random_state=0,max_depth=2)

# %%
model=ml.fit(x_train,y_train)

# %%
res=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_1=accuracy_score(y_test,res)
print("Decision tree :",accuracy_1*100)
# Out:
# Decision tree : 62.1307072515667

# %%
from sklearn import tree
import graphviz
dot_data=tree.export_graphviz(ml,filled=True)
graph = graphviz.Source(dot_data)
graph
